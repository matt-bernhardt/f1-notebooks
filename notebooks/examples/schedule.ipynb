# %% [markdown]
# # Schedule explorer
#
# This is messing around with how event schedules are represetnted in FastF1.

# %%
# Load packages
import fastf1 as ff1

# Load schedule
schedule = ff1.get_event_schedule(2025)

# %%
schedule
# Out:
#     RoundNumber               Country           Location  \
# 0             0               Bahrain             Sakhir
# 1             1             Australia          Melbourne
# 2             2                 China           Shanghai
# 3             3                 Japan             Suzuka
# 4             4               Bahrain             Sakhir
# 5             5          Saudi Arabia             Jeddah
# 6             6         United States              Miami
# 7             7                 Italy              Imola
# 8             8                Monaco             Monaco
# 9             9                 Spain          Barcelona
# 10           10                Canada           Montréal
# 11           11               Austria          Spielberg
# 12           12        United Kingdom        Silverstone
# 13           13               Belgium  Spa-Francorchamps
# 14           14               Hungary           Budapest
# ...

# %%
schedule.columns
# Out:
# Index(['RoundNumber', 'Country', 'Location', 'OfficialEventName', 'EventDate',
#        'EventName', 'EventFormat', 'Session1', 'Session1Date',
#        'Session1DateUtc', 'Session2', 'Session2Date', 'Session2DateUtc',
#        'Session3', 'Session3Date', 'Session3DateUtc', 'Session4',
#        'Session4Date', 'Session4DateUtc', 'Session5', 'Session5Date',
#        'Session5DateUtc', 'F1ApiSupport'],
#       dtype='object')

# %% [markdown]
# ---
#
# This is the end of the notebook.
